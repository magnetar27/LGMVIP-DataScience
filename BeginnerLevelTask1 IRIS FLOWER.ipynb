# %% [markdown]
# # LGMVIP-DataScience

# %% [markdown]
# # Iris Flowers Classification ML Project :

# %% [markdown]
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.

# %%
import pandas as pd

# %%
iris=pd.read_csv('C://Users/Amaan/Desktop/iris.csv')

# %%
df=iris.copy(deep=True)
df.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(df.shape)
# Out:
# (150, 5)

# %%
print(df.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
#Drop by Label
#The drop() function is used to drop specified labels from rows or columns.
df.drop(3, inplace = True)  
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa

# %%
df.index
# Out:
# Int64Index([  0,   1,   2,   4,   5,   6,   7,   8,   9,  10,
#             ...
#             140, 141, 142, 143, 144, 145, 146, 147, 148, 149],
#            dtype='int64', length=149)

# %%
#Drop  by position
df.drop(df.index[0], inplace = True)
df.drop(df.index[[0,1]], inplace = True)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 4           5.0          3.6           1.4          0.2  setosa
# 5           5.4          3.9           1.7          0.4  setosa
# 6           4.6          3.4           1.4          0.3  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %%
df.reset_index(drop = True,inplace = True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.0          3.6           1.4          0.2     setosa
# 1             5.4          3.9           1.7          0.4     setosa
# 2             4.6          3.4           1.4          0.3     setosa
# 3             5.0          3.4           1.5          0.2     setosa
# 4             4.4          2.9           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 141           6.7          3.0           5.2          2.3  virginica
# 142           6.3          2.5           5.0          1.9  virginica
# 143           6.5          3.0           5.2          2.0  virginica
# 144           6.2          3.4           5.4          2.3  virginica
# 145           5.9          3.0           5.1          1.8  virginica
#
# [146 rows x 5 columns]

# %%
df.count()
# Out:
# sepal_length    146
# sepal_width     146
# petal_length    146
# petal_width     146
# species         146
# dtype: int64

# %%
c1 = df[df.species == "virginica" ]
c1[c1.petal_length > 5]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 96            6.3          3.3           6.0          2.5  virginica
# 97            5.8          2.7           5.1          1.9  virginica
# 98            7.1          3.0           5.9          2.1  virginica
# 99            6.3          2.9           5.6          1.8  virginica
# 100           6.5          3.0           5.8          2.2  virginica
# 101           7.6          3.0           6.6          2.1  virginica
# 103           7.3          2.9           6.3          1.8  virginica
# 104           6.7          2.5           5.8          1.8  virginica
# 105           7.2          3.6           6.1          2.5  virginica
# 106           6.5          3.2           5.1          2.0  virginica
# 107           6.4          2.7           5.3          1.9  virginica
# 108           6.8          3.0           5.5          2.1  virginica
# 110           5.8          2.8           5.1          2.4  virginica
# 111           6.4          3.2           5.3          2.3  virginica
# 112           6.5          3.0           5.5          1.8  virginica
# 113           7.7          3.8           6.7          2.2  virginica
# 114           7.7          2.6           6.9          2.3  virginica
# 116           6.9          3.2           5.7          2.3  virginica
# 118           7.7          2.8           6.7          2.0  virginica
# 120           6.7          3.3           5.7          2.1  virginica
# 121           7.2          3.2           6.0          1.8  virginica
# 124           6.4          2.8           5.6          2.1  virginica
# 125           7.2          3.0           5.8          1.6  virginica
# 126           7.4          2.8           6.1          1.9  virginica
# 127           7.9          3.8           6.4          2.0  virginica
# 128           6.4          2.8           5.6          2.2  virginica
# 129           6.3          2.8           5.1          1.5  virginica
# 130           6.1          2.6           5.6          1.4  virginica
# 131           7.7          3.0           6.1          2.3  virginica
# 132           6.3          3.4           5.6          2.4  virginica
# 133           6.4          3.1           5.5          1.8  virginica
# 135           6.9          3.1           5.4          2.1  virginica
# 136           6.7          3.1           5.6          2.4  virginica
# 137           6.9          3.1           5.1          2.3  virginica
# 138           5.8          2.7           5.1          1.9  virginica
# 139           6.8          3.2           5.9          2.3  virginica
# 140           6.7          3.3           5.7          2.5  virginica
# 141           6.7          3.0           5.2          2.3  virginica
# 143           6.5          3.0           5.2          2.0  virginica
# 144           6.2          3.4           5.4          2.3  virginica
# 145           5.9          3.0           5.1          1.8  virginica

# %%
min_data=df["sepal_length"].describe()
count1=df["sepal_length"].count()
mean =df["sepal_length"].mean()
print(count1)
print(mean)
min_data
# Out:
# 146
# 5.87123287671233
# count    146.000000
# mean       5.871233
# std        0.821098
# min        4.300000
# 25%        5.125000
# 50%        5.800000
# 75%        6.400000
# max        7.900000
# Name: sepal_length, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
x = df.sepal_length
y = df.petal_length
plt.scatter(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.show()

# %%
import seaborn as sns
import numpy as np

# %%
sns.barplot(x="sepal_length",y="petal_length",data=df,estimator=np.std)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.countplot(x="species",data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.jointplot(x="sepal_width",y="petal_width",data=df,hue="species")

# %%
sns.violinplot(x="species",y="sepal_length",data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.histplot(df['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Count'>

# %%
sns.pairplot(df,hue="species")

# %%
#Correlation

corr = df.corr()
print(corr)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.102269      0.866534     0.810185
# sepal_width      -0.102269     1.000000     -0.420176    -0.354266
# petal_length      0.866534    -0.420176      1.000000     0.960903
# petal_width       0.810185    -0.354266      0.960903     1.000000

# %%
sns.heatmap(corr,annot=True).set_title("Correlation of attributes")
# Out:
# Text(0.5, 1.0, 'Correlation of attributes')

# %%
x = df.drop(columns="species")
y = df["species"]

# %% [markdown]
# # TRAINING AND TESTING DATA

# %% [markdown]
# # K Neighbour Classifier

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 116
# 30
# 116
# 30

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Accuracy of Model:\n",knn.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      1.00      1.00        10
#    virginica       1.00      1.00      1.00         9
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 10  0]
#  [ 0  0  9]]
# Accuracy of Model:
#  97.41379310344827

# %% [markdown]
# # Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier(max_depth=6, random_state=123,criterion='entropy')

dtree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=6, random_state=123)

# %%
y_pred=dtree.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))

accuracy_score(y_test,y_pred)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      1.00      1.00        10
#    virginica       1.00      1.00      1.00         9
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 10  0]
#  [ 0  0  9]]
# 1.0

# %% [markdown]
# # Adaboost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
adb = AdaBoostClassifier(base_estimator = None)
adb.fit(x_train,y_train)



y_pred=adb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))


accuracy_score(y_test,y_pred)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.91      1.00      0.95        10
#    virginica       1.00      0.89      0.94         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 10  0]
#  [ 0  1  8]]
# 0.9666666666666667

# %% [markdown]
# # Naive Bayes Classifier

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)



y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Accuracy of Model:\n",gnb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       0.91      1.00      0.95        10
#    virginica       1.00      0.89      0.94         9
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30
#
# Confusion Matrix:
#  [[11  0  0]
#  [ 0 10  0]
#  [ 0  1  8]]
# Accuracy of Model:
#  95.6896551724138

# %% [markdown]
# #

# %% [markdown]
# # Thank you , Lets Grow More !
